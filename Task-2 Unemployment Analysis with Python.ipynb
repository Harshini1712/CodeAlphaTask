# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
data = pd.read_csv(r"C:\Users\User\Downloads\Unemployment in India (1).csv")

# %%
# Display the first few rows of the dataset
print(data.head())
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
# Check for missing values
print(data.isnull().sum())
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
# Handle missing values
data.dropna(inplace=True)
data
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# 753     West Bengal   30-06-2020    Monthly                              9.86
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0             11999139.0                                     43.24  Rural
# 1             11755881.0                                     42.05  Rural
# 2             12086707.0                                     43.50  Rural
# 3             12285693.0                                     43.97  Rural
# 4             12256762.0                                     44.68  Rural
# ..                   ...                                       ...    ...
# 749           10871168.0                                     44.09  Urban
# 750           10806105.0                                     43.34  Urban
# 751            9299466.0                                     41.20  Urban
# 752            9240903.0                                     40.67  Urban
# 753            9088931.0                                     37.57  Urban
#
# [740 rows x 7 columns]

# %%
# Summary statistics
print(data.describe())
# Out:
#        Estimated Unemployment Rate (%)  Estimated Employed  \
# count                       740.000000        7.400000e+02
# mean                         11.787946        7.204460e+06
# std                          10.721298        8.087988e+06
# min                           0.000000        4.942000e+04
# 25%                           4.657500        1.190404e+06
# 50%                           8.350000        4.744178e+06
# 75%                          15.887500        1.127549e+07
# max                          76.740000        4.577751e+07
#
#        Estimated Labour Participation Rate (%)
# count                               740.000000
# mean                                 42.630122
# std                                   8.111094
# min                                  13.330000
# 25%                                  38.062500
# 50%                                  41.160000
# 75%                                  45.505000
# max                                  72.570000

# %%
# Convert 'Date' column to datetime
data[' Date'] = pd.to_datetime(data[' Date'].str.strip(), format='%d-%m-%Y')
data[' Date']
# Out:
# 0     2019-05-31
# 1     2019-06-30
# 2     2019-07-31
# 3     2019-08-31
# 4     2019-09-30
#          ...
# 749   2020-02-29
# 750   2020-03-31
# 751   2020-04-30
# 752   2020-05-31
# 753   2020-06-30
# Name:  Date, Length: 740, dtype: datetime64[ns]

# %%
# Line plot of unemployment rate over time for a specific region (e.g., Tamil Nadu)
Tamil_Nadu_data = data[data['Region'] == 'Tamil Nadu']

plt.figure(figsize=(12, 6))
sns.lineplot(x=' Date', y=' Estimated Unemployment Rate (%)', data=Tamil_Nadu_data, hue='Area')
plt.title('Unemployment Rate Over Time in Tamil Nadu')
plt.xlabel('Date')
plt.ylabel('Estimated Unemployment Rate (%)')
plt.show()

# %%
# lineplot of unemployment rate by region
plt.figure(figsize=(12, 8))
sns.lineplot(x='Region', y=' Estimated Unemployment Rate (%)', data=data, hue='Area')
plt.title('Boxplot of Unemployment Rate by Region')
plt.xlabel('Region')
plt.ylabel('Estimated Unemployment Rate (%)')
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(data=data, x='Area')
plt.title('Distribution of Area')
plt.show()

# %%
sns.histplot(data=data, x=' Estimated Unemployment Rate (%)', kde=True, hue= 'Area')
plt.title('Distribution of  Estimated Unemployment Rate (%)')
plt.show()

# %%
sns.histplot(data=data, x=' Estimated Employed', kde=True, hue = 'Area')
plt.title('Distribution of  Estimated Employed')
plt.show()

# %%
data = pd.read_csv(r"C:\Users\User\Downloads\Unemployment_Rate_upto_11_2020 (2).csv")

# %%
data.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %%
data.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        267.000000         2.670000e+02
# mean                          12.236929         1.396211e+07
# std                           10.803283         1.336632e+07
# min                            0.500000         1.175420e+05
# 25%                            4.845000         2.838930e+06
# 50%                            9.650000         9.732417e+06
# 75%                           16.755000         2.187869e+07
# max                           75.850000         5.943376e+07
#
#         Estimated Labour Participation Rate (%)   longitude    latitude
# count                                267.000000  267.000000  267.000000
# mean                                  41.681573   22.826048   80.532425
# std                                    7.845419    6.270731    5.831738
# min                                   16.770000   10.850500   71.192400
# 25%                                   37.265000   18.112400   76.085600
# 50%                                   40.390000   23.610200   79.019300
# 75%                                   44.055000   27.278400   85.279900
# max                                   69.690000   33.778200   92.937600

# %%
data.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %%
import datetime as dt
import calendar
import warnings
warnings.filterwarnings("ignore")

# %%
data[' Date']=pd.to_datetime(data[' Date'],dayfirst=True)

# %%
data['month_int']=data[' Date'].dt.month
data.head()
# Out:
#            Region       Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2020-01-31          M                              5.48
# 1  Andhra Pradesh 2020-02-29          M                              5.83
# 2  Andhra Pradesh 2020-03-31          M                              5.79
# 3  Andhra Pradesh 2020-04-30          M                             20.51
# 4  Andhra Pradesh 2020-05-31          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude  month_int
# 0    15.9129     79.74          1
# 1    15.9129     79.74          2
# 2    15.9129     79.74          3
# 3    15.9129     79.74          4
# 4    15.9129     79.74          5

# %%
data.columns= ["Region"," Date"," Frequency",
               " Estimated Unemployment Rate (%)"," Estimated Employed",
               " Estimated Labour Participation Rate (%)","Region.1",
               "longitude","latitude","month_int"]
plt.title("Indian Unemployment")
sns.histplot(x=" Estimated Employed", hue="Region.1", data=data)
plt.show()

# %%
plt.figure(figsize=(12, 10))
plt.title("Indian Unemployment")
sns.histplot(x=" Estimated Unemployment Rate (%)", hue="Region.1", data=data)
plt.show()

# %%
after_lockdown = data[(data['month_int'] >= 4) & (data['month_int'] <=6)]
before_lockdown = data[(data['month_int'] >= 1) & (data['month_int'] <=4)]

# %%
af_lockdown=after_lockdown.groupby('Region')[' Estimated Unemployment Rate (%)'].mean().reset_index()
lockdown= before_lockdown.groupby('Region')[' Estimated Unemployment Rate (%)'].mean().reset_index()
lockdown['unemployment rate before lockdown'] = af_lockdown[' Estimated Unemployment Rate (%)']
lockdown.columns=['state','unemployment rate before lockdown','unemployment rate after lockdown']
lockdown
# Out:
#                state  unemployment rate before lockdown  \
# 0     Andhra Pradesh                             9.4025
# 1              Assam                             6.2250
# 2              Bihar                            20.7425
# 3       Chhattisgarh                             7.2450
# 4              Delhi                            17.6975
# 5                Goa                             7.5650
# 6            Gujarat                             9.3225
# 7            Haryana                            28.5950
# 8   Himachal Pradesh                            13.6575
# 9    Jammu & Kashmir                            19.1200
# 10         Jharkhand                            19.4450
# 11         Karnataka                             9.9425
# 12            Kerala                             9.7225
# 13    Madhya Pradesh                             5.8150
# 14       Maharashtra                             9.0825
# 15         Meghalaya                             4.2150
# 16            Odisha                            10.4650
# 17        Puducherry                            19.8475
# 18            Punjab                             8.8150
# 19         Rajasthan                            13.9325
# 20            Sikkim                            12.9250
# 21        Tamil Nadu                            14.9725
# 22         Telangana                             6.4500
# 23           Tripura                            33.0625
# 24     Uttar Pradesh                            12.0525
# 25       Uttarakhand                             9.2025
# 26       West Bengal                             9.0475
#
#     unemployment rate after lockdown
# 0                          13.750000
# 1                           7.070000
# 2                          36.806667
# 3                           9.380000
# 4                          25.713333
# 5                          14.840000
# 6                          11.340000
# 7                          32.980000
# 8                          14.206667
# 9                          18.330000
# 10                         42.423333
# 11                         19.416667
# 12                         14.860000
# 13                         13.606667
# 14                         15.196667
# 15                          5.700000
# 16                         12.980000
# 17                         46.093333
# 18                         15.913333
# 19                         15.943333
# 20                         10.416667
# 21                         31.730000
# 22                         10.500000
# 23                         28.150000
# 24                         17.140000
# 25                          7.700000
# 26                         14.036667
